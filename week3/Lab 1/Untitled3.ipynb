# %%
from numpy.core.function_base import linspace
import matplotlib.pyplot as plt
import numpy as np

# %%
iter = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000, 5100, 5200, 5300, 5400, 5500, 5600, 5700, 5800, 5900, 6000, 6100, 6200, 6300, 6400, 6500, 6600, 6700, 6800, 6900, 7000, 7100, 7200, 7300, 7400, 7500, 7600, 7700, 7800, 7900, 8000, 8100, 8200, 8300, 8400, 8500, 8600, 8700, 8800, 8900, 9000, 9100, 9200, 9300, 9400, 9500, 9600, 9700, 9800, 9900]
bs = [85, 96, 110, 109, 110, 122, 123, 127, 122, 122, 136, 135, 135, 135, 134, 140, 135, 134, 135, 135, 147, 167, 153, 167, 144, 150, 144, 136, 150, 146, 144, 149, 141, 118, 118, 118, 123, 118, 126, 118, 128, 128, 128, 128, 132, 128, 128, 128, 129, 134, 146, 133, 151, 134, 130, 128, 128, 129, 128, 133, 128, 128, 128, 129, 151, 152, 157, 161, 158, 154, 149, 141, 128, 134, 128, 128, 128, 128, 136, 129, 132, 173, 154, 139, 139, 139, 139, 143, 139, 139, 139, 139, 139, 139, 142, 139, 139, 176, 171]
ss = [310, 643, 922, 1205, 1495, 1833, 2090, 2392, 2691, 2977, 3336, 3578, 3880, 4156, 4460, 4772, 5070, 5351, 5658, 5972, 6255, 6592, 6870, 7151, 7442, 7781, 8061, 8345, 8636, 8919, 9262, 9546, 9818, 10146, 10418, 10748, 11042, 11308, 11605, 11895, 12179, 12486, 12821, 13055, 13395, 13695, 13963, 14265, 14566, 14892, 15154, 15510, 15796, 16052, 16330, 16639, 16935, 17283, 17535, 17818, 18345, 18468, 18752, 19104, 19346, 19612, 19934, 20201, 20627, 20788, 21195, 21379, 21743, 21990, 22325, 22602, 22867, 23257, 23434, 23779, 24068, 24447, 24681, 24969, 25249, 25567, 25878, 26292, 26475, 26810, 27072, 27335, 27664, 27967, 28284, 28607, 29137, 29178, 29578]

# %%
fig, ax = plt.subplots(1, 3)

ax[0].scatter(iter, bs, color = "red")
ax[0].scatter(iter, ss, color = "blue")
ax[0].grid()
ax[1].scatter(iter, ss, color = "blue")
ax[1].grid()
ax[2].scatter(iter, bs, color = "red")
ax[2].grid()


fig.set_figheight(5)
fig.set_figwidth(15)

# %%
iter = [100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950]
longg = [3348, 5266, 9080, 16192, 24294, 27599, 35960, 45463, 56129, 68015, 80956, 95095, 110294, 126571, 143711, 162299, 181937, 202894]
short = [37, 53, 77, 99, 103, 120, 137, 154, 171, 189, 223, 220, 237, 261, 275, 288, 305, 324]

# %%
fig, ax = plt.subplots(1, 3)

ax[0].scatter(iter, longg, color = "blue")
ax[0].scatter(iter, short, color = "red")
ax[0].grid()
ax[1].scatter(iter, short, color = "red")
ax[1].grid()
ax[2].scatter(iter, longg, color = "blue")
ax[2].grid()


fig.set_figheight(5)
fig.set_figwidth(15)
